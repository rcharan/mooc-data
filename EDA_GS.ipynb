# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df = pd.read_csv('./data/studentVle.csv')
df.head()
# Out:
#   code_module code_presentation  id_student  id_site  date  sum_click
# 0         AAA             2013J       28400   546652   -10          4
# 1         AAA             2013J       28400   546652   -10          1
# 2         AAA             2013J       28400   546652   -10          1
# 3         AAA             2013J       28400   546614   -10         11
# 4         AAA             2013J       28400   546714   -10          1

# %%
df.groupby(['code_module','code_presentation','id_student', 'id_site'])['sum_click'].agg(['sum', 'count'])
test = df[df['id_site']==546652]

# %%
testagg= test.groupby(['id_student','code_presentation', 'id_site'])['sum_click'].agg(['sum', 'count'])
testagg
# Out:
#                                       sum  count
# id_student code_presentation id_site
# 11391      2013J             546652    28      8
# 28400      2013J             546652    89     26
# 30268      2013J             546652    46     13
# 31604      2013J             546652    30      9
# 32885      2013J             546652   107     25
# 38053      2013J             546652   159     33
# 45462      2013J             546652    16      8
# 45642      2013J             546652    26     10
# 52130      2013J             546652     4      3
# 53025      2013J             546652    61     15
# 57506      2013J             546652     4      3
# 58873      2013J             546652    20      7
# 59185      2013J             546652    11      5
# 62155      2013J             546652    51     15
# 63400      2013J             546652    42      6
# 70464      2013J             546652    15      5
# 71361      2013J             546652   144     38
# ...

# %%
import seaborn as sns
sns.distplot(testagg['sum'])
plt.show()

# %%
testagg.stack()
# Out:
# id_student  code_presentation  id_site
# 11391       2013J              546652   sum       28
#                                         count      8
# 28400       2013J              546652   sum       89
#                                         count     26
# 30268       2013J              546652   sum       46
#                                         count     13
# 31604       2013J              546652   sum       30
#                                         count      9
# 32885       2013J              546652   sum      107
#                                         count     25
# 38053       2013J              546652   sum      159
#                                         count     33
# 45462       2013J              546652   sum       16
#                                         count      8
# 45642       2013J              546652   sum       26
#                                         count     10
# 52130       2013J              546652   sum        4
# ...

# %%
s1 = df[df['id_student']==28400]
print(s1.shape)
s1.head()
# Out:
# (430, 6)
#   code_module code_presentation  id_student  id_site  date  sum_click
# 0         AAA             2013J       28400   546652   -10          4
# 1         AAA             2013J       28400   546652   -10          1
# 2         AAA             2013J       28400   546652   -10          1
# 3         AAA             2013J       28400   546614   -10         11
# 4         AAA             2013J       28400   546714   -10          1

# %%
s1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 430 entries, 0 to 174007
# Data columns (total 6 columns):
# code_module          430 non-null object
# code_presentation    430 non-null object
# id_student           430 non-null int64
# id_site              430 non-null int64
# date                 430 non-null int64
# sum_click            430 non-null int64
# dtypes: int64(4), object(2)
# memory usage: 43.5+ KB

# %%
s1.code_presentation.unique()
# Out:
# array(['2013J'], dtype=object)

# %%
s1.code_module.unique()
# Out:
# array(['AAA'], dtype=object)

# %%
s1.id_site.unique()
# Out:
# array([546652, 546614, 546714, 546876, 546688, 546662, 546890, 547011,
#        547013, 546871, 546879, 546681, 546732, 546986, 546719, 546731,
#        546883, 547009, 546723, 546903, 546684, 546657, 546654, 546659,
#        546650, 546669, 546672, 546645, 546667, 546900, 546733, 546739,
#        546738, 546734, 546655, 546647, 546735, 546725, 546716, 546702,
#        546676, 546665, 546678, 546658, 546737, 546899, 546686, 546682,
#        546696, 546680, 546687, 546675, 546653, 546692, 546651, 546691,
#        547017, 546685, 546699, 546694, 547001, 546695, 547048, 546728,
#        546717, 546721, 546693, 546648, 547047, 546690, 546683, 546703,
#        546713, 546677, 546697, 546649, 546736, 546656, 546644, 546966,
#        546707, 546711, 546664, 546705])

# %%
s1.groupby(['id_student', 'id_site'])['sum_click'].agg(['sum', 'count'])
# Out:
#                     sum  count
# id_student id_site
# 28400      546614   324     80
#            546644    21      6
#            546645    21      4
#            546647     4      2
#            546648     2      1
#            546649     8      4
#            546650    27     12
#            546651    22     10
#            546652    89     26
#            546653     6      3
#            546654    97     46
#            546655    38     17
#            546656     7      4
#            546657    54     19
#            546658     4      2
#            546659    17      7
#            546662    21      3
#            546664     2      1
#            546665    14      3
#            546667     3      1
#            546669     5      2
#            546672     1      1
#            546675     1      1
#            546676     1      1
#            546677     1      1
#            546678     5      2
#            546680     2      1
#            546681    12      3
# ...
